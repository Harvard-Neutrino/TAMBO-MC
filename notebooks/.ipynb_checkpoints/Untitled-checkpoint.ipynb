# %%
using Revise
using Pkg
Pkg.activate("/Users/jlazar/research/TAMBO-MC/tambo/")
# push!(LOAD_PATH, "/Users/jlazar/research/TAMBO-MC/tambo/src/")
using Tambo
using HDF5
# using Geometries
# using Units
# using Plots
# using Tracks
# using Printf
# Out:
#   Activating project at `~/research/TAMBO-MC/tambo`
# ┌ Info: Precompiling Tambo [d9a96183-4919-46da-8188-64ea4e10e0ed]
# └ @ Base loading.jl:1423
# ┌ Warning: Package Tambo does not have LinearAlgebra in its dependencies:
# │ - If you have Tambo checked out for development and have
# │   added LinearAlgebra as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with Tambo
# └ Loading LinearAlgebra into Tambo from project dependency, future warnings for Tambo are suppressed.
# WARNING: Method definition (::Type{Tambo.Direction})(Any, Any, Any) in module Tambo at /Users/jlazar/research/TAMBO-MC/tambo/src/Geometries.jl:24 overwritten at /Users/jlazar/research/TAMBO-MC/tambo/src/Geometries.jl:35.
#   ** incremental compilation may be fatally broken for this module **
#
# ┌ Info: Precompiling HDF5 [f67ccb44-e63f-5c2f-98bd-6dc0ccc4ba2f]
# └ @ Base loading.jl:1423

# %%
using Random
Random.seed!(4)
# Out:
# TaskLocalRNG()

# %%
begin
    Random.seed!(4)
    ts = TAMBOSim()
    ts.n = 10000
    ts.θmin = 0
    ts.θmax = π
    events = ts()
end;
# Out:
# StaticArrays.SVector{3, Float64}[[-5.6670450258197e10, -9.255962119588487e10, -1.0169721697015208e11], [1.0861128281947554e11, 3.106151752184853e10, -8.493399619157764e8]]
# StaticArrays.SVector{3, Float64}[[1.1753509065934755e10, 2.6226871531105385e10, 2.533865468705e10], [-1.0861128281947554e11, -3.0369014852960648e10, -1.362164192864663e9]]
# MethodError: Cannot `convert` an object of type Float64 to an object of type StaticArrays.SVector{3, Float64}
# Closest candidates are:
#   convert(::Type{StaticArrays.SVector{N, T}}, ::CartesianIndex{N}) where {N, T} at ~/.julia/packages/StaticArrays/KyWYI/src/SVector.jl:42
#   convert(::Type{T}, ::LinearAlgebra.Factorization) where T<:AbstractArray at /Applications/Julia-1.7.app/Contents/Resources/julia/share/julia/stdlib/v1.7/LinearAlgebra/src/factorization.jl:58
#   convert(::Type{SA}, ::Tuple) where SA<:StaticArrays.StaticArray at ~/.julia/packages/StaticArrays/KyWYI/src/convert.jl:13
#   ...
#
# Stacktrace:
#   [1] Tambo.Direction(θ::Float64, ϕ::Float64, proj::Float64)
#     @ Tambo ~/research/TAMBO-MC/tambo/src/Geometries.jl:24
#   [2] Tambo.Direction(sv::StaticArrays.SVector{3, Float64})
#     @ Tambo ~/research/TAMBO-MC/tambo/src/Geometries.jl:43
#   [3] Tambo.Direction(ip::StaticArrays.SVector{3, Float64}, fp::StaticArrays.SVector{3, Float64})
#     @ Tambo ~/research/TAMBO-MC/tambo/src/Geometries.jl:47
#   [4] Tambo.Track(ipoint::StaticArrays.SVector{3, Float64}, fpoint::StaticArrays.SVector{3, Float64})
#     @ Tambo ~/research/TAMBO-MC/tambo/src/Tracks.jl:27
#   [5] _broadcast_getindex_evalf
#     @ ./broadcast.jl:670 [inlined]
#   [6] _broadcast_getindex
#     @ ./broadcast.jl:643 [inlined]
#   [7] getindex
#     @ ./broadcast.jl:597 [inlined]
#   [8] copy
#     @ ./broadcast.jl:899 [inlined]
#   [9] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, Type{Tambo.Track}, Tuple{Vector{StaticArrays.SVector{3, Float64}}, Vector{StaticArrays.SVector{3, Float64}}}})
#     @ Base.Broadcast ./broadcast.jl:860
#  [10] inject_events(ts::TAMBOSim)
#     @ Tambo ~/research/TAMBO-MC/tambo/src/Tambo.jl:262
#  [11] (::TAMBOSim)()
#     @ Tambo ~/research/TAMBO-MC/tambo/src/Tambo.jl:57
#  [12] top-level scope
#     @ In[18]:7
#  [13] eval
#     @ ./boot.jl:373 [inlined]
#  [14] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196

# %%
# @time begin
#     Random.seed!(4)
#     ts = TAMBOSim()
#     ts.n = 1000
#     ts.θmin = π/2
#     ts.θmax = π
#     events = ts()
# end;

# %%
for field in fieldnames(Tambo.Event)
    println((field, getfield(events[1],field)))
end
# Out:
# (:e, 1.83413269483608e15)
# (:θ, 2.318168399927375)
# (:ϕ, 4.189784917640179)
# (:impact_parameter, 3.027793568175276e9)
# (:ψ, 0.28441115569013964)
# (:incoming_track, Tracks.Track(Geometries.TPoint(-2.2300145017268453e9, 1.9509638377323725e9, -6.231447002359191e8), Geometries.TPoint(-5.6670450258197e10, -9.255962119588487e10, -1.0169721697015208e11), Geometries.Direction(2.318168399927375, 4.189784917640179, -0.3661067854030847, -0.6355747523404096, -0.6797135837021698), 1.4870097448898978e11))
# (:outgoing_track, Tracks.Track(Geometries.TPoint(-2.2300145017268453e9, 1.9509638377323725e9, -6.231447002359191e8), Geometries.TPoint(1.1753509065934755e10, 2.6226871531105385e10, 2.533865468705e10), Geometries.Direction(0.8234242536624183, 1.0481922640503862, 0.3661067854030846, 0.6355747523404097, 0.6797135837021699), 3.8195204582907974e10))
# (:column_depth, 1.7300551166462045e30)
# (:interaction_vertex, Geometries.TPoint(-3.887538585299752e10, -6.1666739383372574e10, -6.865891371731337e10))
# (:p_near, Geometries.TPoint(-2.2300145017268453e9, 1.9509638377323725e9, -6.231447002359191e8))
# (:tr, Tracks.Track(Geometries.TPoint(-5.6670450258197e10, -9.255962119588487e10, -1.0169721697015208e11), Geometries.TPoint(1.1753509065934755e10, 2.6226871531105385e10, 2.533865468705e10), Geometries.Direction(0.8234242536624184, 1.0481922640503862, 0.36610678540308467, 0.6355747523404097, 0.6797135837021698), 1.8689617907189774e11))
# (:λ_int, 0.2600706621039323)

# %%
d0 = Dict(
    :e=>"energy",
    :θ=>"zenith",
    :ϕ=>"azimuth",
    :ψ=>"psi",
    :impact_parameter=>"impact_parameter",
    :incoming_track=>"incoming_track",
    :outgoing_track=>"outgoing_track",
    :column_depth=>"column_depth",
    :interaction_vertex=>"interaction_vertex",
    :p_near=>"p_near",
    :tr=>"tr",
    :λ_int=>"affine_int",
#     :p_int=>"p_int"
)
dtrack = Dict(
    :ipoint=>Dict(
        :x=>"ix",
        :y=>"iy",
        :z=>"iz"
    ),
    :fpoint=>Dict(
        :x=>"fx",
        :y=>"fy",
        :z=>"fz"
    )
)
dpt = Dict(
    :x=>"x",
    :y=>"y",
    :z=>"z"
)

# d1 = 
# fname = tempname()
fname = "/Users/jlazar/research/TAMBO-MC/10000_all_sky_injection_check.h5"
h5open(fname, "w") do fid
    for fn in fieldnames(Tambo.Event)
        saveable = [getfield(e, fn) for e in events]
        if typeof(saveable[1])==Tambo.TPoint
            for x in [:x, :y,:z]
                dset_name = d0[fn] * "_" * dpt[x]
                fid[dset_name] = getfield.(saveable, x)./Units.m

            end
        elseif typeof(saveable[1])==Tambo.Track
            for fn1 in [:ipoint, :fpoint]
                for x in [:x, :y, :z]
                    dset_name = d0[fn]* "_" * dtrack[fn1][x]
                    fid[dset_name] = getfield.(getfield.(saveable, fn1), x)./Units.m
                end
            end
        elseif d0[fn]=="energy"
            fid[d0[fn]] = [getfield(e, fn)/Units.GeV for e in events]
        elseif d0[fn]=="impact_parameter"
            fid[d0[fn]] = [getfield(e, fn)/Units.m for e in events]
        elseif d0[fn]=="column_depth"
            fid[d0[fn]] = [getfield(e, fn)/(Units.gr/Units.cm^2) for e in events]
        else
            fid[d0[fn]] = [getfield(e, fn) for e in events]
        end
    end
end

# %%
fid = h5open(fname, "r")
maximum(sqrt.(fid["interaction_vertex_x"][].^2 .+fid["interaction_vertex_y"][].^2 .+fid["interaction_vertex_z"][].^2))
# close(fid)
# Out:
# 37335.828782538825

# %%
b = []
for x in xx./m .+ 21431.935546875
    push!(b, [g.spl(x,y)[1] for y in yy./m .+ 18264.509765625])
#     println()
end
# Out:
# type Geometry has no field spl
#
# Stacktrace:
#  [1] getproperty(x::Geometry, f::Symbol)
#    @ Base ./Base.jl:42
#  [2] (::var"#3#4"{Float64})(y::Float64)
#    @ Main ./none:0
#  [3] iterate
#    @ ./generator.jl:47 [inlined]
#  [4] collect(itr::Base.Generator{LinRange{Float64, Int64}, var"#3#4"{Float64}})
#    @ Base ./array.jl:724
#  [5] top-level scope
#    @ In[9]:3
#  [6] eval
#    @ ./boot.jl:373 [inlined]
#  [7] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
c = []
for x in xx./m .+ 21431.935546875
    push!(c, [spl(x,y)[1] for y in yy./m .+ 18264.509765625])
#     println()
end
# Out:
# UndefVarError: spl not defined
#
# Stacktrace:
#  [1] (::var"#5#6"{Float64})(y::Float64)
#    @ Main ./none:0
#  [2] iterate
#    @ ./generator.jl:47 [inlined]
#  [3] collect(itr::Base.Generator{LinRange{Float64, Int64}, var"#5#6"{Float64}})
#    @ Base ./array.jl:724
#  [4] top-level scope
#    @ In[10]:3
#  [5] eval
#    @ ./boot.jl:373 [inlined]
#  [6] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
ts = Tambo.TAMBOSim()
ts.n = 1000
# ts.ϕmin = π/2
# ts.ϕmax = π/2
# ts.θmin = 0
# ts.θmax = 0
# ts.r_injection = 0
ts.l_endcap = 10km
Tambo.verify_ts!(ts)

# %%
e = rand(ts.n, ts.pl)
# Out:
# 1000-element Vector{Float64}:
#  1.6220657274140562e15
#  1.4906429203573112e15
#  2.776173533879392e15
#  1.567502856809001e15
#  1.2589333093430732e15
#  1.1670324720143822e15
#  1.0237629510378276e15
#  1.8804150811054282e15
#  1.0124667433627224e15
#  2.2396691240697358e15
#  1.4832143960442782e15
#  1.9167604722899335e15
#  7.6964230454897e15
#  ⋮
#  1.836387442341802e15
#  5.199451544175663e15
#  1.9745382967075152e15
#  2.811050000271106e15
#  2.4689423253346785e15
#  1.9068635499615695e15
#  3.632325241834694e15
#  3.4381907998085155e15
#  1.3193632766093808e15
#  1.0061215809201641e15
#  1.0152511284804572e15
#  1.4726422178978518e15

# %%
range = Tambo.lepton_range.(e, Ref(ts.ν_pdg))
println("The range in mwe is")
println(range[1]/(100Units.gr/Units.cm^2))
# Out:
# The range in mwe is
# 101778.99543737766

# %%
# θ = acos.(rand(ts.n) .* (cos(ts.θmin)-cos(ts.θmax)) .+ cos(ts.θmax))
# # println("θ is:")
# # println(θ[1])
# # println()
# # Randomly sample azimuth
# ϕ = rand(ts.n) .* (ts.ϕmax-ts.ϕmin) .+ ts.ϕmin
# # println("ϕ is:")
# # println(ϕ[1])
# # println()
# b = ts.r_injection .* sqrt.(rand(ts.n))
# # println("The impact parameter in meters is:")
# # println(b[1] / m)
# # println()
# ψ = rand(ts.n) .* 2π
# p_near = TPoint.(Tambo.perpendicular_plane.(θ, ϕ, b, ψ))
# # println("The point of closest approach in meters is:")
# # println(p_near[1]/m)
# # println()
# # println("The impact parameter after rotation in meters is:")
# # println(sqrt(sum(p_near[1].x^2+p_near[1].z^2+p_near[1].y^2))/m)
# # println()
# ti = Track.(p_near, Tracks.Direction.(θ, ϕ), Ref(ts.geo.box))
# # println("The incoming track is:")
# # println(ti[1])
# # println()
# # println("And it intersects the box at")
# # println(ti[1].fpoint/m)
# # println()
# # println("Its total column depth in mwe is")
# # println(total_column_depth(ti[1], ts.geo.valley) ./ (100Units.gr/Units.cm^2))
# # println()
# # Make track from point of closest approach to point of exit
# to = Track.(p_near, Tracks.Direction.(π.-θ, mod.(ϕ.+π, 2π)), Ref(ts.geo.box))
# # println("The outgoing track is:")
# # println(to[1])
# # println()
# # println("And it intersects the box at")
# # println(to[1].fpoint/m)
# # println()
# # println("Its total column depth in mwe is")
# # println(total_column_depth(to[1], ts.geo.valley)/mwe)
# # println()
# x = Tambo.sample_column_depth.(ti, to, Ref(ts), range)
# cd = [v[1] for v in x]
# tr = [v[2] for v in x]
# # println(tr.fpoint/m)
# λ_int = Tracks.inverse_column_depth.(tr, cd, Ref(ts.geo.valley))
# p_int = [tr[i](λ_int[i]) for i in eachindex(tr)]

# %%
p_near_m = p_near./m
sct = scatter3d(getfield.(p_near_m, :x), getfield.(p_near_m, :y), getfield.(p_near_m, :z), alpha=0.1)
# plot(sct)

# %%
p_int_m = p_int./m
xx = getfield.(p_int_m, :x)
yy = getfield.(p_int_m, :y)
zz = getfield.(p_int_m, :z)
xrange = LinRange(minimum(xx), maximum(xx), 51)
yrange = LinRange(-20000, 20000, 200)
plt = plot([], [])
for xlxh in zip(xrange[1:end-1], xrange[2:end])
# @gif for xlxh in zip(xrange[1:end-1], xrange[2:end])
    xl, xh = xlxh
    mask = xx.>=xl .&& xx.<=xh
#     plt = scatter(yy[mask], zz[mask], alpha=0.2)
    scatter!(plt, yy[mask], zz[mask], alpha=0.2)
    plot!(plt, yrange, ts.geo.(Ref(sum(xlxh)*m/2), yrange.*m)./m)
    plot!(plt, legend=false, xlim=(-20000, 20000), ylim=(-3e4, 3e3), xlabel="Y [m]", ylabel="Z [m]")
    string_xl = @sprintf("%5.0f",xl)
    string_xh = @sprintf("%5.0f",xh)
    string_xlxh = string_xl * " m<=x<" * string_xh*" m"
    println(string_xl * ", " * string_xh)
    annotate!(plt, -1.9e4, -2.75e4, text(string_xlxh, :left, 9, "sans_serif"))
#     display(plt)
    if xl==xrange[2]
        break
    end
end
display(plot)

# %%
p_int_m = p_int./m
xx = getfield.(p_int_m, :x)
sct = scatter3d(getfield.(p_int_m, :x), getfield.(p_int_m, :y), getfield.(p_int_m, :z), alpha=0.1)
scatter!(sct, [0], [0], [0])
plot!(ylim=(-4000, 4000), zlim=(-4e3, 3e3))
scatter!(sct, camera=(90,0))

# %%
function muon_range(emu)
    emu_gev = emu / GeV
    da = 0.212/1.2
    db = 0.251e-3/1.2
    1 / db * log(1 + emu_gev*da/db)
end

ee = 10 .^ LinRange(4, 12, 200) .* GeV
plt = plot(ee./GeV, Tambo.lepton_range.(ee, Ref(16))./mwe, label="τ")
plot!(ee./GeV, Tambo.lepton_range.(ee, Ref(14))./mwe, label="μ")
plot(plt, xaxis=:log, yaxis=:log, xlabel="E_{ν} [GeV]", ylabel="Range [mwe]")

# %%
function muon_range(emu)
    emu_gev = emu / GeV
    da = 0.212/1.2
    db = 0.251e-3/1.2
    1 / db * log(1 + emu_gev*da/db)
end

ee = 10 .^ LinRange(4, 12, 200) .* GeV
plt = plot(ee./GeV, Tambo.lepton_range.(ee, Ref(16))./mwe, label="τ")
plot!(ee./GeV, Tambo.lepton_range.(ee, Ref(14))./mwe, label="μ")
plot(plt, xaxis=:log, yaxis=:log, xlabel="E_{ν} [GeV]", ylabel="Range [mwe]")

# %%
a = h5open("/Users/jlazar/research/TAMBO-MC/100_injection_check.h5")
# Out:
# 🗂️ HDF5.File: (read-only) /Users/jlazar/research/TAMBO-MC/100_injection_check.h5
# ├─ 🔢 affine_int
# ├─ 🔢 azimuth
# ├─ 🔢 column_depth
# ├─ 🔢 energy
# ├─ 🔢 impact_parameter
# ├─ 🔢 incoming_track_fx
# ├─ 🔢 incoming_track_fy
# ├─ 🔢 incoming_track_fz
# ├─ 🔢 incoming_track_ix
# ├─ 🔢 incoming_track_iy
# ├─ 🔢 incoming_track_iz
# ├─ 🔢 interaction_vertex_x
# ├─ 🔢 interaction_vertex_y
# ├─ 🔢 interaction_vertex_z
# ├─ 🔢 outgoing_track_fx
# ├─ 🔢 outgoing_track_fy
# ├─ 🔢 outgoing_track_fz
# ├─ 🔢 outgoing_track_ix
# ├─ 🔢 outgoing_track_iy
# ├─ 🔢 outgoing_track_iz
# ├─ 🔢 p_near_x
# ├─ 🔢 p_near_y
# ├─ 🔢 p_near_z
# ├─ 🔢 psi
# ├─ 🔢 tr_fx
# ├─ 🔢 tr_fy
# ├─ 🔢 tr_fz
# ├─ 🔢 tr_ix
# ├─ 🔢 tr_iy
# ├─ 🔢 tr_iz
# └─ 🔢 zenith

# %%
maximum(sqrt.(sum([a["interaction_vertex_x"][].^2 .+ a["interaction_vertex_y"][].^2 .+ a["interaction_vertex_z"][].^2])))
# Out:
# 32616.63495231152

# %%
b = a["interaction_vertex_z"][] .- ts.geo.valley.(a["interaction_vertex_x"][], a["interaction_vertex_y"][])
# Out:
# 100-element Vector{Float64}:
#   -2270.93779893718
#  -13735.985726691013
#    2817.196861567982
#   -6912.195307013913
#   -6107.919376693339
#   -9089.539852955962
#   -4149.6745244883205
#    -834.5600128269016
#    -665.8654655938522
#   -1090.3728305997572
#    2398.489883309287
#    -669.2335856389057
#    1519.125432624531
#       ⋮
#    2177.150888889283
#     119.61413698089314
#   -8392.137085817503
#    -828.939565256353
#   -1097.0151669684114
#   -6066.477096501893
#  -15636.199074869313
#    -744.129795865954
#   -5569.719745434462
#     202.20395969411322
#   -6194.773354250528
#  -14120.927113604559

# %%
b[b.>0]
# Out:
# 17-element Vector{Float64}:
#  2817.196861567982
#  2398.489883309287
#  1519.125432624531
#   135.88500106564226
#  2196.1863041382603
#  3801.228660112806
#  3826.6622986879497
#  3705.0519966302877
#  2125.0798196425885
#  2873.2220342816768
#  2671.1911253036214
#  1342.2765006973004
#  5155.831096888257
#  3537.1670924790496
#  2177.150888889283
#   119.61413698089314
#   202.20395969411322

# %%
for i in 1:100
    e = events[i]
    ts.geo.valley(e.interaction_vertex.x, e.interaction_vertex.y)
    d = e.interaction_vertex.z - ts.geo.valley(e.interaction_vertex.x, e.interaction_vertex.y)
    if d < 0
        println((d, i))
    end
end
# Out:
# (-6.11944234021936e9, 15)
# (-4.735825702138729e8, 98)

# %%
events[15].tr
# Out:
# Tracks.Track(Geometries.TPoint(-6.63233906003174e10, -9.255962119588487e10, -9.876960740310022e9), Geometries.TPoint(6.87992686483302e10, 9.255962119588487e10, 4.2772060634052844e9), Geometries.Direction(1.5091168500874146, 0.9402692735516496, 0.5884494364341836, 0.8061809504363364, 0.061640375679070755), 2.2962492761901163e11)
